# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("pp.csv")

# %%
data
#represent dataset
# Out:
#                                            example  credit_score  employment  \
# 0   1.        high        good       yes       yes           NaN         NaN
# 1  2.        medium        no         no        no           NaN         NaN
# 2   3.       high         no          yes       no           NaN         NaN
# 3   4.       medium       yes         yes       no           NaN         NaN
#
#    colletral  loan approval
# 0        NaN            NaN
# 1        NaN            NaN
# 2        NaN            NaN
# 3        NaN            NaN

# %%
concepts = np.array(data)[:,:-1]

# %%
concepts
# Out:
# array([['1.        high        good       yes       yes', nan, nan, nan],
#        ['2.        medium        no         no        no', nan, nan, nan],
#        ['3.       high         no          yes       no', nan, nan, nan],
#        ['4.       medium       yes         yes       no', nan, nan, nan]],
#       dtype=object)

# %%
target = np.array(data)[:,-1]

# %%
target
# Out:
# array([nan, nan, nan, nan], dtype=object)

# %%
def train(con,tar):
    for i,val in enumerate(tar):
        if val == 'yes':
           specific_h = con[i].copy()
           break
        
    for i, val in enumerate(con):
        if tar[i] == 'yes':
           for x in range(len(specific_h)):
            if val[x] != specific_h[x]:
                specific_h[x] = '?'
           else:
                pass
                return specific_h

# %% [raw]
# print(train(concepts,target))
